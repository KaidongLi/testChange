# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/PEP_2017_unit_change/PEP_2017_PEPANNCHHU.US01_with_ann.csv')
unit_change = data[2:]
unit_change.numdiff20162017 = pd.to_numeric(unit_change.numdiff20162017)
unit_change
# Out:
#        GEO.id GEO.id2 GEO.display-label GC.target-geo-id GC.target-geo-id2  \
# 2   0100000US     NaN     United States      0400000US01                01
# 3   0100000US     NaN     United States      0400000US02                02
# 4   0100000US     NaN     United States      0400000US04                04
# 5   0100000US     NaN     United States      0400000US05                05
# 6   0100000US     NaN     United States      0400000US06                06
# 7   0100000US     NaN     United States      0400000US08                08
# 8   0100000US     NaN     United States      0400000US09                09
# 9   0100000US     NaN     United States      0400000US10                10
# 10  0100000US     NaN     United States      0400000US11                11
# 11  0100000US     NaN     United States      0400000US12                12
# 12  0100000US     NaN     United States      0400000US13                13
# ...

# %%
plt_unit = unit_change.plot(x='GC.display-label.1', y='numdiff20162017', kind='bar', figsize=(15, 10))
plt_unit.set_xlabel("state")
plt_unit.set_ylabel("change_per")
# Out:
# Text(0,0.5,'change_per')

# %%
data = pd.read_csv('data/ACS_16_5YR_income/ACS_16_5YR_GCT1901.ST05_with_ann.csv')

income = data[data['GEO.id2'] == data['GCT_STUB.target-geo-id2']]
income.HC01 = pd.to_numeric(income.HC01)

#income = pd.DataFrame()
#num_row = len(data.index)
#for i in range(1, num_row):
#    income_row = data.iloc[[i]]
#    geo_id = pd.to_numeric(income_row['GEO.id2'])
#    print type(geo_id)
#    print geo_id
#    if (income_row['GEO.id2'] == income_row['GCT_STUB.target-geo-id2']):
#        print "true"
#    income = income.append()
    #print i
    #income = income.append(row)

#data[50:100]
data[0:1]
#income
# Out:
#   GEO.id GEO.id2 GEO.display-label GCT_STUB.target-geo-id  \
# 0     Id     Id2         Geography          Target Geo Id
#
#   GCT_STUB.target-geo-id2 GCT_STUB.display-label GCT_STUB.display-label.1  \
# 0          Target Geo Id2        Geographic Area          Geographic Area
#
#      HC01             HC02
# 0  Dollar  Margin of Error

# %%
plt_income = income.plot(x='GCT_STUB.display-label', y='HC01', kind='bar', figsize=(15, 10))
plt_income.set_xlabel("state-county")
plt_income.set_ylabel("income")
# Out:
# Text(0,0.5,'income')

# %%
data = pd.read_csv('data/PEP_2017_census/PEP_2017_PEPANNRES_with_ann.csv')

popu = data[2:53]
popu.respop72017 = pd.to_numeric(popu.respop72017)
#popu

# %%
plt_popu = popu.plot(x='GEO.display-label', y='respop72017', kind='bar', figsize=(15, 10))
plt_popu.set_xlabel("state")
plt_popu.set_ylabel("population")
# Out:
# Text(0,0.5,'population')

# %%
#popu GEO.display-label respop72017
#unit_change GC.display-label.1 numdiff20162017
#unit_change.numdiff20162017.size
#unit_change.numdiff20162017[2]

for i, change in unit_change.numdiff20162017.items():
    #print("change: " + repr(change))
    #print("population: " + repr(popu.respop72017[i]))
    unit_change.numdiff20162017[i] = change * 10000 / popu.respop72017[i]
unit_change
# Out:
# /home/kaidong/Softwares/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#        GEO.id GEO.id2 GEO.display-label GC.target-geo-id GC.target-geo-id2  \
# 2   0100000US     NaN     United States      0400000US01                01
# 3   0100000US     NaN     United States      0400000US02                02
# 4   0100000US     NaN     United States      0400000US04                04
# 5   0100000US     NaN     United States      0400000US05                05
# 6   0100000US     NaN     United States      0400000US06                06
# 7   0100000US     NaN     United States      0400000US08                08
# 8   0100000US     NaN     United States      0400000US09                09
# ...

# %%
data_final = pd.DataFrame();
data_final['id'] = unit_change['GC.target-geo-id2'];
data_final['display-label'] = unit_change['GC.display-label.1']
data_final
# Out:
#     id         display-label
# 2   01               Alabama
# 3   02                Alaska
# 4   04               Arizona
# 5   05              Arkansas
# 6   06            California
# 7   08              Colorado
# 8   09           Connecticut
# 9   10              Delaware
# 10  11  District of Columbia
# 11  12               Florida
# 12  13               Georgia
# 13  15                Hawaii
# 14  16                 Idaho
# 15  17              Illinois
# 16  18               Indiana
# 17  19                  Iowa
# 18  20                Kansas
# 19  21              Kentucky
# 20  22             Louisiana
# 21  23                 Maine
# 22  24              Maryland
# 23  25         Massachusetts
# 24  26              Michigan
# 25  27             Minnesota
# 26  28           Mississippi
# 27  29              Missouri
# 28  30               Montana
# 29  31              Nebraska
# 30  32                Nevada
# 31  33         New Hampshire
# 32  34            New Jersey
# ...
